# %% [markdown]
# <a href="https://colab.research.google.com/github/lyj12h/ai_m/blob/main/practice/0913.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##0913 Machine Learning for AI - Practice

# %%
import pandas as pd

# %%
team= {
    'name' : ['김후정','이연주','손약정','김성연'],
    'hobby' : ['신문독서','유튜브 보기','양궁','맛집탐방'],
    'nationality' :['한국','한국','중국','한국'],
    'major' : ['문헌','도시','통계','통계']
}

team
# Out:
# {'name': ['김후정', '이연주', '손약정', '김성연'],
#  'hobby': ['신문독서', '유튜브 보기', '양궁', '맛집탐방'],
#  'nationality': ['한국', '한국', '중국', '한국'],
#  'major': ['문헌', '도시', '통계', '통계']}

# %%
team_pandas= pd.DataFrame(team)

team_pandas
# Out:
#   name   hobby nationality major
# 0  김후정    신문독서          한국    문헌
# 1  이연주  유튜브 보기          한국    도시
# 2  손약정      양궁          중국    통계
# 3  김성연    맛집탐방          한국    통계

# %%
##index 수정
###이름을 index로 지정

team_pandas.set_index('name',inplace=True)
team_pandas
# Out:
#        hobby nationality major
# name
# 김후정     신문독서          한국    문헌
# 이연주   유튜브 보기          한국    도시
# 손약정       양궁          중국    통계
# 김성연     맛집탐방          한국    통계

# %%
##csv로 저장
team_pandas.to_csv("0913_practice.csv")

# %%
##csv 불러오기
pd.read_csv("0913_practice.csv")
# Out:
#   name   hobby nationality major
# 0  김후정    신문독서          한국    문헌
# 1  이연주  유튜브 보기          한국    도시
# 2  손약정      양궁          중국    통계
# 3  김성연    맛집탐방          한국    통계
